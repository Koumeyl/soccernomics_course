# %%
from statsbombpy import sb
import matplotlib.pyplot as plt

from mplsoccer import Pitch, VerticalPitch

# %%
sb.competitions()
# Out:
# /home/kb/personal_projects/soccernomics_course/env/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# ...

# %%
world_cup_df=sb.matches(competition_id=43, season_id=106)
world_cup_df.head(5)
# Out:
#    match_id  match_date      kick_off                     competition season  \
# 0   3869254  2022-12-06  21:00:00.000  International - FIFA World Cup   2022
# 1   3869118  2022-12-04  21:00:00.000  International - FIFA World Cup   2022
# 2   3869486  2022-12-10  17:00:00.000  International - FIFA World Cup   2022
# 3   3869685  2022-12-18  17:00:00.000  International - FIFA World Cup   2022
# 4   3869684  2022-12-17  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  ...  \
# 0   Portugal  Switzerland           6           1    available  ...
# 1    England      Senegal           3           0    available  ...
# 2    Morocco     Portugal           1           0    available  ...
# 3  Argentina       France           3           3    available  ...
# 4    Croatia      Morocco           2           1    available  ...
#
#              last_updated_360 match_week competition_stage  \
# ...

# %%
argentina_matches = world_cup_df[(world_cup_df.home_team.str.contains("Argentina")) | (world_cup_df.away_team.str.contains("Argentina"))].sort_values(by="match_date")
argentina_matches.reset_index()
# Out:
#    index  match_id  match_date      kick_off                     competition  \
# 0     28   3857300  2022-11-22  12:00:00.000  International - FIFA World Cup
# 1     38   3857289  2022-11-26  21:00:00.000  International - FIFA World Cup
# 2     56   3857264  2022-11-30  21:00:00.000  International - FIFA World Cup
# 3     13   3869151  2022-12-03  21:00:00.000  International - FIFA World Cup
# 4      9   3869321  2022-12-09  21:00:00.000  International - FIFA World Cup
# 5      5   3869519  2022-12-13  21:00:00.000  International - FIFA World Cup
# 6      3   3869685  2022-12-18  17:00:00.000  International - FIFA World Cup
#
#   season    home_team     away_team  home_score  away_score  ...  \
# 0   2022    Argentina  Saudi Arabia           1           2  ...
# 1   2022    Argentina        Mexico           2           0  ...
# 2   2022       Poland     Argentina           0           2  ...
# 3   2022    Argentina     Australia           2           1  ...
# ...

# %%
events = sb.events(match_id=3869685)
events.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_other', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_penalty', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'foul_won_penalty', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'interception_outcome', 'location', 'match_id', 'minute', 'off_camera',
# ...

# %%
passes = events.loc[events['type'] == 'Pass'].loc[events['pass_type'] != 'Throw-in'].set_index('id')
passes["pass_type"].unique()
passes["player"].unique()

#Lionel Andrés Messi Cuccittini
# Out:
# array(['Antoine Griezmann', 'Aurélien Djani Tchouaméni',
#        'Rodrigo Javier De Paul', 'Cristian Gabriel Romero',
#        'Nicolás Hernán Otamendi', 'Nicolás Alejandro Tagliafico',
#        'Damián Emiliano Martínez', 'Theo Bernard François Hernández',
#        'Adrien Rabiot', 'Raphaël Varane', 'Jules Koundé',
#        'Alexis Mac Allister', 'Lionel Andrés Messi Cuccittini',
#        'Ángel Fabián Di María Hernández', 'Hugo Lloris', 'Olivier Giroud',
#        'Enzo Fernandez', 'Nahuel Molina Lucero', 'Kylian Mbappé Lottin',
#        'Ousmane Dembélé', 'Julián Álvarez', 'Dayotchanculle Upamecano',
#        'Randal Kolo Muani', 'Marcus Thuram', 'Marcos Javier Acuña',
#        'Eduardo Camavinga', 'Kingsley Coman', 'Gonzalo Ariel Montiel',
#        'Youssouf Fofana', 'Leandro Daniel Paredes',
#        'Lautaro Javier Martínez', 'Ibrahima Konaté',
#        'Paulo Bruno Exequiel Dybala', 'Germán Alejandro Pezzella'],
#       dtype=object)

# %%
pitch = Pitch(pitch_type = 'statsbomb', pitch_color='black', line_color='white', linewidth=1)
# specifying figure size (width, height)
fig, ax = pitch.draw(figsize=(10, 7))



for i,thepass in passes.iterrows():
    #if pass made by Lucy Bronze
    if thepass['player']=='Lionel Andrés Messi Cuccittini':
        x=thepass['location'][0]
        y=thepass['location'][1]
        #plot circle
        passCircle=plt.Circle((x,y),2,color="blue")
        passCircle.set_alpha(.2)
        ax.add_patch(passCircle)
        dx=thepass["pass_end_location"][0]-x
        dy=thepass['pass_end_location'][1]-y
        #plot arrow
        passArrow=plt.Arrow(x,y,dx,dy,width=3,color="#6CACE4")
        ax.add_patch(passArrow)

ax.set_title("Lionel Messi passes in the WC final", fontsize = 20)
fig.set_size_inches(10, 7)
plt.show()

# %%
pitch = Pitch(pitch_type = 'statsbomb', pitch_color='black', line_color='white', linewidth=1)
# specifying figure size (width, height)
fig, ax = pitch.draw(figsize=(10, 7))



for i,thepass in passes.iterrows():
    #if pass made by Lucy Bronze
    if thepass['player']=='Kylian Mbappé Lottin':
        x=thepass['location'][0]
        y=thepass['location'][1]
        #plot circle
        passCircle=plt.Circle((x,y),2,color="blue")
        passCircle.set_alpha(.2)
        ax.add_patch(passCircle)
        dx=thepass["pass_end_location"][0]-x
        dy=thepass['pass_end_location'][1]-y
        #plot arrow
        passArrow=plt.Arrow(x,y,dx,dy,width=3,color="#6CACE4")
        ax.add_patch(passArrow)

ax.set_title("Kylian mbappe passes in the WC final", fontsize = 24)
fig.set_size_inches(10, 7)
plt.show()

# %%
mask_bronze = (events.type == 'Pass') & (events.player == "Kylian Mbappé Lottin")
df_pass = events.loc[mask_bronze, ['location'] ['pass_end_location']]


pitch = Pitch(line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
pitch.arrows(df_pass.location[0], df_pass.location[1],
            df_pass.pass_end_location[0], df_pass.pass_end_location[1], color = "blue", ax=ax['pitch'])
pitch.scatter(df_pass.location[0], df_pass.location[1], alpha = 0.2, s = 500, color = "blue", ax=ax['pitch'])
fig.suptitle("Lucy Bronze passes against Sweden", fontsize = 30)
plt.show()
# Out:
# 59       [38.8, 46.8]
# 74        [68.7, 5.9]
# 145      [99.1, 19.2]
# 198       [81.8, 5.1]
# 210      [86.7, 14.1]
# 248       [98.0, 0.1]
# 250      [105.9, 5.5]
# 370      [66.8, 10.6]
# 394      [87.1, 10.4]
# 488       [91.8, 4.7]
# 626      [74.1, 15.1]
# 702       [71.3, 2.5]
# 705      [97.6, 17.7]
# 764      [67.0, 18.1]
# 779      [79.0, 17.0]
# 784      [92.9, 15.8]
# 800       [98.9, 8.7]
# 873       [60.2, 7.6]
# 891      [93.1, 24.1]
# 919     [108.3, 20.3]
# 937      [74.7, 63.0]
# 939      [80.3, 61.5]
# 951      [92.3, 25.4]
# 967      [86.7, 18.1]
# 986       [79.4, 4.6]
# 987     [110.9, 23.5]
# 1245      [79.0, 4.2]
# Name: location, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/personal_projects/soccernomics_course/env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
# ...
